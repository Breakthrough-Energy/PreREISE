# %%
import numpy as np
import pandas as pd

from datetime import datetime
from dateutil.parser import parse

# %%
BAlist = ['AVA']

for x in BAlist:
    filename = x + '.xlsx'
    dirname = 'U:\Data\WECC_demand_2015-2018'
    df = pd.read_excel(io = dirname + "/" + filename, header = 0)

# %%
df.head()
# Out:
#     BA            UTC Time       Date  Hour          Local Time Time Zone  \
# 0  AVA 2015-07-01 08:00:00 2015-07-01     1 2015-07-01 01:00:00   Pacific
# 1  AVA 2015-07-01 09:00:00 2015-07-01     2 2015-07-01 02:00:00   Pacific
# 2  AVA 2015-07-01 10:00:00 2015-07-01     3 2015-07-01 03:00:00   Pacific
# 3  AVA 2015-07-01 11:00:00 2015-07-01     4 2015-07-01 04:00:00   Pacific
# 4  AVA 2015-07-01 12:00:00 2015-07-01     5 2015-07-01 05:00:00   Pacific
#
#   Generation Only      DF       D     NG   ...    Balance CHPD  Balance GCPD  \
# 0               N  1413.0  1192.0  371.0   ...             0.0           0.0
# 1               N  1336.0  1108.0  358.0   ...             0.0           0.0
# 2               N  1291.0  1058.0  343.0   ...             0.0           0.0
# 3               N  1265.0  1024.0  338.0   ...             0.0           0.0
# 4               N  1277.0  1031.0  330.0   ...             0.0           0.0
#
# ...

# %%
type(df['UTC Time'][1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp
