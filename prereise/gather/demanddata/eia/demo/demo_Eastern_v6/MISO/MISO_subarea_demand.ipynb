# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read in 2016 MISO demand data

# %%
LRZ_demand_2016 = pd.read_excel('20161231_dfal_hist.xls', skiprows=5)
LRZ_demand_2016
# Out:
#                                                MarketDay HourEnding  \
# 0                                    2016-01-01 00:00:00          1
# 1                                    2016-01-01 00:00:00          1
# 2                                    2016-01-01 00:00:00          1
# 3                                    2016-01-01 00:00:00          1
# 4                                    2016-01-01 00:00:00          1
# 5                                    2016-01-01 00:00:00          1
# 6                                    2016-01-01 00:00:00          1
# 7                                    2016-01-01 00:00:00          2
# 8                                    2016-01-01 00:00:00          2
# 9                                    2016-01-01 00:00:00          2
# 10                                   2016-01-01 00:00:00          2
# 11                                   2016-01-01 00:00:00          2
# 12                                   2016-01-01 00:00:00          2
# ...

# %% [markdown]
# Replace nans with predicted values

# %%
LRZ_demand.loc[LRZ_demand['ActualLoad (MWh)'].isna() , 'ActualLoad (MWh)'] = LRZ_demand['MTLF (MWh)']
LRZ_demand

# %% [markdown]
# Read in 2015 MISO demand data

# %%
LRZ_demand_2015 = pd.read_excel('C:\\Users\\dmuldrew\\Dropbox (IVL)\\Explorations\\DanM\\20151231_dfal_hist.xls', skiprows=5)
LRZ_demand_2015
# Out:
#                                                MarketDay HourEnding  \
# 0                                    2015-01-01 00:00:00          1
# 1                                    2015-01-01 00:00:00          1
# 2                                    2015-01-01 00:00:00          1
# 3                                    2015-01-01 00:00:00          1
# 4                                    2015-01-01 00:00:00          1
# 5                                    2015-01-01 00:00:00          1
# 6                                    2015-01-01 00:00:00          1
# 7                                    2015-01-01 00:00:00          2
# 8                                    2015-01-01 00:00:00          2
# 9                                    2015-01-01 00:00:00          2
# 10                                   2015-01-01 00:00:00          2
# 11                                   2015-01-01 00:00:00          2
# 12                                   2015-01-01 00:00:00          2
# ...

# %%
miso_zones = ['LRZ1','LRZ2_7','LRZ3_5','LRZ4','LRZ6','LRZ8_9_10']

def CreateDemandProfile(data, miso_zones, startdate, enddate):
    demand = pd.DataFrame(data[data['LoadResource Zone'] == miso_zones[0]]['ActualLoad (MWh)'])
    for zone in range(1,len(miso_zones)):
        demand[miso_zones[zone]] = data[data['LoadResource Zone'] == miso_zones[zone]]['ActualLoad (MWh)'].to_list()
    demand.columns = miso_zones
    
    #start_date = pd.to_datetime(startdate)
    #end_date = pd.to_datetime(enddate)
    #time_interval = pd.date_range(start_date, end_date, tz = "US/Eastern", freq='H')
    #demand.index = time_interval
    #demand.tz_convert('utc')
    
    return demand

# %%
startdate = pd.to_datetime('2015-10-01 01:00:00')
enddate = pd.to_datetime('2016-12-01 00:00:00')
MISO_loadzones_2015 = CreateDemandProfile(LRZ_demand_2015, miso_zones, startdate, enddate)
MISO_loadzones_2015
# Out:
#           LRZ1    LRZ2_7    LRZ3_5     LRZ4      LRZ6  LRZ8_9_10
# 0      11566.6  16866.75  10673.85  5687.05  11594.30   18887.39
# 7      11128.9  16232.87  10440.79  5540.74  11449.76   18462.71
# 14     10744.2  15752.56  10206.73  5436.40  11292.13   18250.65
# 21     10516.3  15413.05  10086.26  5361.72  11198.64   18014.31
# 28     10369.1  15325.18  10041.79  5324.75  11125.65   17934.87
# 35     10335.9  15472.11  10154.53  5354.31  11255.00   18008.60
# 42     10501.8  15799.27  10318.95  5434.42  11418.44   18302.87
# 49     10702.6  16185.31  10519.45  5537.95  11564.77   18668.21
# 56     10847.4  16334.72  10527.70  5524.95  11501.08   18806.34
# 63     11065.2  16781.55  10649.18  5593.12  11611.09   19275.53
# 70       11341  17267.23  10721.42  5690.01  11551.59   19755.16
# 77     11535.3  17625.63  10621.72  5711.36  11477.15   20001.94
# 84       11634  17730.18  10496.69  5635.19  11290.66   19972.88
# ...

# %%
start_date = pd.to_datetime('2016-10-01 01:00:00')
end_date = pd.to_datetime('2017-12-01 00:00:00')
MISO_loadzones_2016 = CreateDemandProfile(LRZ_demand_2016, miso_zones, startdate, enddate)
MISO_loadzones_2016
# Out:
#           LRZ1    LRZ2_7    LRZ3_5     LRZ4      LRZ6  LRZ8_9_10
# 0      10911.1  15824.53  10006.74  5198.81   9963.71   17483.79
# 7      10560.7  15271.17   9879.14  4968.12   9842.67   17121.95
# 14     10211.5  14792.03   9751.33  4858.49   9740.47   16969.39
# 21     9977.08  14462.12   9602.58  4831.48   9629.32   16820.69
# 28     9870.24  14392.40   9622.67  4804.95   9701.47   16797.15
# 35     9897.06  14541.61   9692.37  4856.01   9888.91   16965.46
# 42     10096.7  14886.83   9853.55  4970.98  10131.83   17392.22
# 49     10296.6  15351.13  10111.77  5070.41  10315.24   17941.20
# 56     10506.7  15622.51  10188.25  5061.51  10352.28   18293.29
# 63     10617.4  16011.85  10070.44  5181.92  10481.42   18843.33
# 70     10853.8  16544.85  10076.23  5250.89  10637.38   19413.83
# 77     11006.5  16938.96  10002.35  5306.10  10810.02   19750.73
# 84     10963.3  17118.67   9952.27  5311.75  10791.26   19729.04
# ...

# %%
demand_15_16 = pd.concat([MISO_loadzones_2015, MISO_loadzones_2016])
sstart = pd.to_datetime('2016-01-01 00:00:00')
end = pd.to_datetime('2016-12-31 23:00:00')
MISO_demand_2016 = demand_15_16.loc[start:end]

# %%
MISO_demand_2016.to_csv('miso_subarea_demand_profile_2016.csv')

# %%
LRZ_demand = pd.read_excel('20161231_dfal_hist.xls')
LRZ_demand

# %%
LRZ_demand.loc[LRZ_demand['ActualLoad (MWh)'].isna() , 'ActualLoad (MWh)'] = LRZ_demand['MTLF (MWh)']

# %%
LRZ_demand

# %%
LRZ_demand_2015 = pd.read_excel('C:\\Users\\dmuldrew\\Dropbox (IVL)\\Explorations\\DanM\\20151231_dfal_hist.xls', skiprows=5)
LRZ_demand_2015

# %%
miso_zones = ['LRZ1','LRZ2_7','LRZ3_5','LRZ4','LRZ6','LRZ8_9_10']
MISO_loadzones_2015 = pd.DataFrame(LRZ_demand_2015[LRZ_demand_2015['LoadResource Zone'] == miso_zones[0]]['ActualLoad (MWh)'])
MISO_loadzones_2015.columns = [miso_zones[0]]
for zone in range(1,len(miso_zones)):
    MISO_loadzones_2015[miso_zones[zone]] = LRZ_demand_2015[LRZ_demand_2015['LoadResource Zone'] == miso_zones[zone]]['ActualLoad (MWh)'].to_list()

# %%
start_date = pd.to_datetime('2015-01-01 01:00:00')
end_date = pd.to_datetime('2016-01-01 00:00:00')
time_interval = pd.date_range(start_date, end_date, tz = "US/Eastern", freq='H')
MISO_loadzones_2015.index = time_interval
MISO_loadzones_2015

# %%
start_date = pd.to_datetime('2015-10-01 01:00:00')
end_date = pd.to_datetime('2016-12-01 00:00:00')

# %%
MISO_loadzones = pd.DataFrame(LRZ_demand[LRZ_demand['LoadResource Zone'] == 'LRZ1']['ActualLoad (MWh)'])
MISO_loadzones.columns = ['LRZ1']

# %%
MISO_loadzones['LRZ2_7'] = LRZ_demand[LRZ_demand['LoadResource Zone'] == 'LRZ2_7']['ActualLoad (MWh)'].to_list()

# %%
MISO_loadzones['LRZ3_5'] = LRZ_demand[LRZ_demand['LoadResource Zone'] == 'LRZ3_5']['ActualLoad (MWh)'].to_list()

# %%
MISO_loadzones['LRZ4'] = LRZ_demand[LRZ_demand['LoadResource Zone'] == 'LRZ4']['ActualLoad (MWh)'].to_list()

# %%
MISO_loadzones['LRZ6'] = LRZ_demand[LRZ_demand['LoadResource Zone'] == 'LRZ6']['ActualLoad (MWh)'].to_list()

# %%
MISO_loadzones['LRZ8_9_10'] = LRZ_demand[LRZ_demand['LoadResource Zone'] == 'LRZ8_9_10']['ActualLoad (MWh)'].to_list()

# %%
MISO_loadzones

# %%
start_date = pd.to_datetime('2016-01-01 01:00:00')
end_date = pd.to_datetime('2017-01-01 00:00:00')
time_interval = pd.date_range(start_date, end_date, tz = "US/Eastern", freq='H')

# %%
MISO_loadzones.index = time_interval
MISO_loadzones

# %%
demand_15_16 = pd.concat([MISO_loadzones_2015, MISO_loadzones])
demand_15_16

# %%
start = pd.to_datetime('2016-03-13 00:00:00')
end = pd.to_datetime('2016-03-14 23:00:00')
preshift = demand_15_16.loc[start:end]
preshift

# %%
utc_demand_15_16 = demand_15_16.tz_convert('utc')

# %%
start = pd.to_datetime('2016-03-13 00:00:00')
end = pd.to_datetime('2016-03-14 23:00:00')
preshift = demand_15_16.loc[start:end]
preshift

# %%
start = pd.to_datetime('2016-01-01 00:00:00')
end = pd.to_datetime('2016-12-31 23:00:00')
MISO_demand_2016 = utc_demand_15_16.loc[start:end]

# %%
MISO_demand_2016

# %%
import os
os.getcwd()

# %%
MISO_demand_2016.to_csv('.\\Eastern_Demand_Improvement\\miso_subarea_demand_profile_2016.csv')

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}
# us_state_abbrev = set(us_state_abbrev.values())

# %%
state_to_MISO_demand_zones = {'North Dakota':'LRZ1', 'Montana':'LRZ1', 'South Dakota':'LRZ1','Minnesota':'LRZ1','Iowa':'LRZ3_5', 'Missouri':'LRZ3_5',\
'Wisconsin': 'LRZ2_7', 'Michigan': 'LRZ2_7', 'Illinois':'LRZ4','Indiana': 'LRZ6', 'Texas': 'LRZ8_9_10',\
'Louisiana': 'LRZ8_9_10','Arkansas':'LRZ8_9_10','Alabama':'LRZ8_9_10','Mississippi': 'LRZ8_9_10','Kentucky':'LRZ6'}

# %%
import json
data = json.load(open('C:\\Users\\dmuldrew\\Downloads\\mapchartSave__usa_counties__.txt'))
data

# %%
MISO_minority_report = {}
for val in data['groups'].values():
    MISO_minority_report[val['label']] = set(val['paths'])
MISO_minority_report

# %%
bus_ba_map = pd.read_csv("C:\\Users\\dmuldrew\\Dropbox (IVL)\\Explorations\\BainanX\\Eastern Demand Improvement\\bus_ba_map.csv", index_col = 0)
bus_ba_map

# %%
miso = bus_ba_map[bus_ba_map['BA'] == 'MISO']
miso

# %%
miso['state'] = miso['County'].str.split('__').str[-1]
miso

# %%
inverted_us_state_abbrev = {val:key for key,val in us_state_abbrev.items()}
inverted_us_state_abbrev

# %%
state_to_MISO_demand_zones

# %%
def get_MISO_demand_zone(inverted_us_state_abbrev, state_to_MISO_demand_zones, state_abbrev):
    mapped_zone = np.nan
    valid_state_abbrev = state_abbrev in inverted_us_state_abbrev.keys()
    if valid_state_abbrev:
        in_MISO_mapping = inverted_us_state_abbrev[state_abbrev] in state_to_MISO_demand_zones
        if in_MISO_mapping:
            mapped_zone =  state_to_MISO_demand_zones[inverted_us_state_abbrev[state_abbrev]]
    return mapped_zone

# %%
get_MISO_demand_zone(inverted_us_state_abbrev, state_to_MISO_demand_zones,'CA')

# %%
from functools import partial
MISO_demand_zone = partial(get_MISO_demand_zone,inverted_us_state_abbrev,state_to_MISO_demand_zones)

# %%
miso['miso_zone'] = miso.apply(lambda x: MISO_demand_zone(x['state']), axis=1)
miso

# %%
miso[miso['miso_zone'].isnull()].state.unique()

# %%
miso[miso['miso_zone'].isnull()]

# %%
miso.loc[40644,'miso_zone'] = 'LRZ2_7'

# %%
MISO_minority_report

# %%
miso[miso['County'] == 'Chippewa__WI']

# %%
miso_copy = miso

for zone,counties in MISO_minority_report.items():
    for county in counties:
        print(county)
        print(zone)
        miso_copy.loc[miso['County'] == county,'miso_zone'] = zone
        print(miso_copy[miso['County'] == county]['miso_zone'])

# %%
miso_copy

# %%
miso_copy.to_csv('.\\Eastern_Demand_Improvement\\MISO_mapping.csv')
