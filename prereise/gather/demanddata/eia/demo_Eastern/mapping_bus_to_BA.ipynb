# %% [markdown]
# # Descriptions

# %% [markdown]
# # For each county, get list of BAs who serve the county

# %%
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
dir_files = '../test/data/'

county_utility_file = 'Service_Territory_2016.xlsx'  #get utility-county mapping
ba_utility_file = 'Sales_Ult_Cust_2016.xlsx'  #Get utility-BA mapping
# ba_list_file = 'Balancing_Authority_2016.xlsx'  #list of BAs by state

county_utility =  pd.read_excel(io = dir_files + '/' + county_utility_file, 
                                   dtype = {'Utility Number': str, 'County': str, 'State': str}
                               )
ba_utility = pd.read_excel(io = dir_files + '/' + ba_utility_file, 
                          usecols = 'B,G,I,W', skiprows = [0,1], 
                          dtype = {'Utility Number': str, 'BA_CODE': str, 'State': str},
                          sheet_name = 'States'
                          )
ba_county = pd.merge(county_utility, ba_utility, how='outer', on ='Utility Number')

# %%
county_utility.head()
# Out:
#    Data Year Utility Number              Utility Name State     County
# 0       2016             34  City of Abbeville - (SC)    SC  Abbeville
# 1       2016             55   City of Aberdeen - (MS)    MS     Monroe
# 2       2016             59  City of Abbeville - (LA)    LA  Vermilion
# 3       2016             84       A & N Electric Coop    MD   Somerset
# 4       2016             84       A & N Electric Coop    VA   Accomack

# %%
ba_utility.head()
# Out:
#   Utility Number State BA_CODE Megawatthours.4
# 0             55    AL     TVA               0
# 1             55    MS     TVA          201106
# 2             59    LA    MISO          132078
# 3             84    MD     PJM            2565
# 4             84    VA     PJM          672045

# %%
ba_county.head()
# Out:
#    Data Year Utility Number              Utility Name State_x     County  \
# 0     2016.0             34  City of Abbeville - (SC)      SC  Abbeville
# 1     2016.0             55   City of Aberdeen - (MS)      MS     Monroe
# 2     2016.0             55   City of Aberdeen - (MS)      MS     Monroe
# 3     2016.0             59  City of Abbeville - (LA)      LA  Vermilion
# 4     2016.0             84       A & N Electric Coop      MD   Somerset
#
#   State_y BA_CODE Megawatthours.4
# 0     NaN     NaN             NaN
# 1      AL     TVA               0
# 2      MS     TVA          201106
# 3      LA    MISO          132078
# 4      MD     PJM            2565

# %%
ba_county_uniq = ba_county[['BA_CODE','County','State_x','State_y']].drop_duplicates(keep='first')
ba_county_uniq.drop(columns = ['State_y'], inplace=True)
ba_county_uniq.rename(columns = {'State_x':'State'}, inplace=True)
ba_county_uniq.dropna(axis = 0, how = 'any', inplace=True)
ba_county_uniq.drop_duplicates(keep = 'first', inplace=True)

# %%
ba_county_uniq.head()
# Out:
#   BA_CODE       County State
# 1     TVA       Monroe    MS
# 3    MISO    Vermilion    LA
# 4     PJM     Somerset    MD
# 6     PJM     Accomack    VA
# 8     PJM  Northampton    VA

# %%
county_ba_dict = defaultdict(list)
state_ba_dict = defaultdict(set)
for index,row in ba_county_uniq.iterrows():
    county_state = str(row['County']) + '_' + str(row['State'])
    county_ba_dict[county_state].append(row['BA_CODE'])
    state = str(row['State'])
    state_ba_dict[state].add(row['BA_CODE'])

# %%
county_ba_dict['Lincoln_NV']
# Out:
# []

# %%
state_ba_dict
# Out:
# defaultdict(set,
#             {'MS': {'MISO', 'SOCO', 'TVA'},
#              'LA': {'MISO', 'SWPP'},
#              'MD': {'PJM'},
#              'VA': {'LGEE', 'PJM', 'TVA'},
#              'IL': {'EEI', 'MISO', 'PJM'},
#              'WI': {'MISO'},
#              'OH': {'OVEC', 'PJM'},
#              'NY': {'ISNE', 'NYIS', 'PJM'},
#              'GA': {'DUK', 'SEPA', 'SOCO', 'TVA'},
#              'MN': {'MISO', 'PACW', 'SWPP', 'WACM', 'WALC'},
#              'SC': {'CPLE', 'DUK', 'SC', 'SCEG'},
#              'AZ': {'AZPS',
#               'PACE',
#               'PACW',
#               'PNM',
#               'SRP',
#               'SWPP',
#               'TEPC',
#               'WACM',
#               'WALC'},
#              'AL': {'AEC', 'MISO', 'SOCO', 'TVA'},
#              'FL': {'AEC',
#               'FMPP',
#               'FPC',
#               'FPL',
#               'GVL',
#               'HST',
#               'JEA',
#               'NSB',
#               'SEC',
#               'SOCO',
#               'TAL',
#               'TEC'},
#              'CA': {'BANC',
#               'CISO',
#               'IID',
#               'LDWP',
#               'NEVP',
#               'PACE',
#               'PACW',
#               'SWPP',
#               'TIDC',
#               'WACM',
#               'WALC'},
#              'NC': {'CPLE', 'DUK', 'PJM', 'TVA'},
#              'IN': {'LGEE', 'MISO', 'PJM'},
#              'KS': {'SWPP'},
#              'OK': {'AECI', 'MISO', 'PNM', 'SWPP'},
#              'MI': {'MISO', 'PJM'},
#              'IA': {'AECI', 'MISO', 'PACW', 'SWPP', 'WACM', 'WALC'},
#              'NE': {'PACW', 'SWPP', 'WACM', 'WALC'},
#              'TN': {'CPLE', 'LGEE', 'MISO', 'PJM', 'TVA'},
#              'AK': {'AMPL', 'CEA'},
#              'KY': {'EEI', 'LGEE', 'MISO', 'PJM', 'TVA'},
#              'WV': {'PJM'},
#              'AR': {'AECI', 'MISO', 'SPA', 'SWPP'},
#              'OR': {'AVA',
#               'BPAT',
#               'IPCO',
#               'PACE',
#               'PACW',
#               'PGE',
#               'SWPP',
#               'WACM',
#               'WALC'},
#              'CO': {'PACW', 'PNM', 'PSCO', 'SWPP', 'WACM', 'WALC'},
#              'MO': {'AECI', 'MISO', 'PACW', 'SPA', 'SWPP', 'WACM', 'WALC'},
#              'NJ': {'NYIS', 'PJM'},
#              'TX': {'EPE', 'ERCO', 'MISO', 'PNM', 'SWPP'},
#              'ME': {'ISNE', 'NBSO'},
#              'ND': {'MISO', 'PACW', 'SWPP', 'WACM', 'WALC', 'WAUW'},
#              'WY': {'BPAT',
#               'NWMT',
#               'PACE',
#               'PACW',
#               'PSCO',
#               'SWPP',
#               'WACM',
#               'WALC',
#               'WAUW'},
#              'MT': {'AVA',
#               'BPAT',
#               'NWMT',
#               'PACW',
#               'SWPP',
#               'WACM',
#               'WALC',
#               'WAUW'},
#              'MA': {'ISNE'},
#              'WA': {'AVA',
#               'BPAT',
#               'CHPD',
#               'DOPD',
#               'GCPD',
#               'PACE',
#               'PACW',
#               'PSEI',
#               'SCL',
#               'TPWR'},
#              'SD': {'MISO', 'PACW', 'SWPP', 'WACM', 'WALC'},
#              'NV': {'BPAT', 'CISO', 'NEVP', 'PACW', 'SWPP', 'WACM', 'WALC'},
#              'UT': {'BPAT', 'NEVP', 'PACE', 'PACW', 'SWPP', 'WACM', 'WALC'},
#              'CT': {'ISNE'},
#              'ID': {'AVA', 'BPAT', 'IPCO', 'NWMT', 'PACE', 'PACW'},
#              'VT': {'ISNE'},
#              'NM': {'EPE',
#               'ERCO',
#               'PACE',
#               'PACW',
#               'PNM',
#               'SWPP',
#               'WACM',
#               'WALC'},
#              'PA': {'NYIS', 'PJM'},
#              'DE': {'PJM'},
#              'RI': {'ISNE'},
#              'NH': {'ISNE'},
#              'DC': {'PJM'},
#              'HI': {'HECO'}})

# %%
# for keys, values in county_ba_dict.items():
#     if not values:
#         print (keys)
county_ba_dict
# Out:
# defaultdict(list,
#             {'Monroe_MS': ['TVA'],
#              'Vermilion_LA': ['MISO'],
#              'Somerset_MD': ['PJM'],
#              'Accomack_VA': ['PJM'],
#              'Northampton_VA': ['PJM'],
#              'Adams_IL': ['MISO'],
#              'Brown_IL': ['MISO'],
#              'Schuyler_IL': ['MISO'],
#              'Adams_WI': ['MISO'],
#              'Columbia_WI': ['MISO'],
#              'Dane_WI': ['MISO'],
#              'Dodge_WI': ['MISO'],
#              'Green Lake_WI': ['MISO'],
#              'Jefferson_WI': ['MISO'],
#              'Marquette_WI': ['MISO'],
#              'Portage_WI': ['MISO'],
#              'Sauk_WI': ['MISO'],
#              'Waupaca_WI': ['MISO'],
#              'Waushara_WI': ['MISO'],
#              'Wood_WI': ['MISO'],
#              'Adams_OH': ['PJM'],
#              'Brown_OH': ['PJM'],
#              'Highland_OH': ['PJM'],
#              'Pike_OH': ['PJM', 'OVEC'],
#              'Scioto_OH': ['PJM'],
#              'Cattaraugus_NY': ['NYIS'],
#              'Erie_NY': ['NYIS'],
#              'Wyoming_NY': ['NYIS'],
#              'Cook_GA': ['SOCO'],
#              'Tift_GA': ['SOCO'],
#              'Nobles_MN': ['MISO', 'SWPP'],
#              'Big Stone_MN': ['MISO', 'SWPP'],
#              'Pope_MN': ['MISO'],
#              'Stevens_MN': ['MISO', 'SWPP', 'WALC', 'WACM', 'PACW'],
#              'Swift_MN': ['MISO', 'WALC', 'WACM', 'SWPP', 'PACW'],
#              'Aiken_SC': ['SC', 'SCEG'],
#              'Barnwell_SC': ['SC', 'SCEG'],
#              'Calhoun_SC': ['SC', 'SCEG'],
#              'Edgefield_SC': ['SC', 'DUK', 'SCEG'],
#              'Greenwood_SC': ['SC', 'DUK', 'SCEG'],
#              'Lexington_SC': ['SC', 'SCEG'],
#              'McCormick_SC': ['SC', 'DUK', 'SCEG'],
#              'Orangeburg_SC': ['SC', 'SCEG'],
#              'Saluda_SC': ['SC', 'DUK', 'SCEG'],
#              'Pima_AZ': ['AZPS', 'WALC', 'TEPC', 'WACM', 'SWPP', 'PACW'],
#              'Autauga_AL': ['SOCO', 'AEC'],
#              'Baldwin_AL': ['SOCO', 'AEC'],
#              'Barbour_AL': ['SOCO', 'AEC'],
#              'Bibb_AL': ['SOCO', 'AEC'],
#              'Blount_AL': ['SOCO'],
#              'Bullock_AL': ['SOCO', 'AEC'],
#              'Butler_AL': ['SOCO', 'AEC'],
#              'Calhoun_AL': ['SOCO', 'TVA', 'AEC'],
#              'Chambers_AL': ['SOCO', 'AEC'],
#              'Cherokee_AL': ['SOCO', 'TVA'],
#              'Chilton_AL': ['SOCO', 'AEC'],
#              'Choctaw_AL': ['SOCO'],
#              'Clarke_AL': ['SOCO', 'AEC'],
#              'Clay_AL': ['SOCO', 'AEC'],
#              'Cleburne_AL': ['SOCO', 'AEC'],
#              'Coffee_AL': ['SOCO', 'AEC'],
#              'Conecuh_AL': ['SOCO', 'AEC'],
#              'Coosa_AL': ['SOCO', 'AEC'],
#              'Covington_AL': ['SOCO', 'AEC'],
#              'Crenshaw_AL': ['SOCO', 'AEC'],
#              'Cullman_AL': ['SOCO', 'TVA'],
#              'Dale_AL': ['SOCO', 'AEC'],
#              'Dallas_AL': ['SOCO', 'AEC'],
#              'Elmore_AL': ['SOCO', 'AEC'],
#              'Escambia_AL': ['SOCO', 'AEC'],
#              'Etowah_AL': ['SOCO', 'TVA', 'AEC'],
#              'Fayette_AL': ['SOCO'],
#              'Franklin_AL': ['SOCO', 'TVA'],
#              'Geneva_AL': ['SOCO', 'AEC'],
#              'Greene_AL': ['SOCO'],
#              'Hale_AL': ['SOCO'],
#              'Henry_AL': ['SOCO', 'AEC'],
#              'Houston_AL': ['SOCO', 'AEC'],
#              'Jefferson_AL': ['SOCO', 'TVA'],
#              'Lamar_AL': ['SOCO'],
#              'Lawrence_AL': ['SOCO', 'TVA'],
#              'Lee_AL': ['SOCO', 'AEC'],
#              'Lowndes_AL': ['SOCO', 'AEC'],
#              'Macon_AL': ['SOCO', 'AEC'],
#              'Marengo_AL': ['SOCO'],
#              'Marion_AL': ['SOCO'],
#              'Marshall_AL': ['SOCO', 'TVA'],
#              'Mobile_AL': ['SOCO', 'MISO'],
#              'Monroe_AL': ['SOCO', 'AEC'],
#              'Montgomery_AL': ['SOCO', 'AEC'],
#              'Perry_AL': ['SOCO', 'AEC'],
#              'Pickens_AL': ['SOCO'],
#              'Randolph_AL': ['SOCO', 'AEC'],
#              'Russell_AL': ['SOCO', 'AEC'],
#              'Shelby_AL': ['SOCO', 'AEC'],
#              'St Clair_AL': ['SOCO', 'AEC'],
#              'Sumter_AL': ['SOCO'],
#              'Talladega_AL': ['SOCO', 'AEC'],
#              'Tallapoosa_AL': ['SOCO', 'AEC'],
#              'Tuscaloosa_AL': ['SOCO'],
#              'Walker_AL': ['SOCO'],
#              'Washington_AL': ['SOCO', 'MISO', 'AEC'],
#              'Wilcox_AL': ['SOCO', 'AEC'],
#              'Winston_AL': ['SOCO', 'TVA'],
#              'Alachua_FL': ['FPC', 'SEC', 'FPL', 'GVL'],
#              'Alameda_CA': ['CISO', 'WALC', 'WACM', 'SWPP', 'PACW'],
#              'Dougherty_GA': ['SOCO'],
#              'Lee_GA': ['SOCO'],
#              'Stanly_NC': ['DUK', 'CPLE'],
#              'Camden_NC': ['PJM'],
#              'Chowan_NC': ['PJM', 'CPLE'],
#              'Currituck_NC': ['PJM'],
#              'Pasquotank_NC': ['PJM', 'CPLE'],
#              'Perquimans_NC': ['PJM'],
#              'Warrick_IN': ['MISO'],
#              'Alcorn_MS': ['TVA'],
#              'Douglas_MN': ['MISO'],
#              'Barber_KS': ['SWPP'],
#              'Harper_KS': ['SWPP'],
#              'Alfalfa_OK': ['SWPP'],
#              'Garfield_OK': ['SWPP', 'AECI'],
#              'Grant_OK': ['SWPP'],
#              'Major_OK': ['SWPP'],
#              'Woods_OK': ['SWPP'],
#              'Rapides_LA': ['MISO'],
#              'Alger_MI': ['MISO'],
#              'Delta_MI': ['MISO'],
#              'Dickinson_MI': ['MISO'],
#              'Marquette_MI': ['MISO'],
#              'Menominee_MI': ['MISO'],
#              'Schoolcraft_MI': ['MISO'],
#              'Kewaunee_WI': ['MISO'],
#              'Bartow_GA': ['SOCO'],
#              'Cobb_GA': ['SOCO'],
#              'Kossuth_IA': ['SWPP', 'MISO'],
#              'Allamakee_IA': ['MISO'],
#              'Bremer_IA': ['MISO', 'SWPP'],
#              'Chickasaw_IA': ['MISO', 'SWPP'],
#              'Clayton_IA': ['MISO'],
#              'Delaware_IA': ['MISO'],
#              'Dubuque_IA': ['MISO'],
#              'Fayette_IA': ['MISO', 'SWPP'],
#              'Winneshiek_IA': ['MISO'],
#              'Box Butte_NE': ['SWPP', 'WACM', 'WALC', 'PACW'],
#              'Morrill_NE': ['SWPP', 'WACM', 'WALC', 'PACW'],
#              'Alcona_MI': ['MISO'],
#              'Alpena_MI': ['MISO'],
#              'Montmorency_MI': ['MISO'],
#              'Presque Isle_MI': ['MISO'],
#              'Emanuel_GA': ['SOCO'],
#              'Johnson_GA': ['SOCO'],
#              'Laurens_GA': ['SOCO'],
#              'Montgomery_GA': ['SOCO'],
#              'Tattnall_GA': ['SOCO'],
#              'Toombs_GA': ['SOCO'],
#              'Treutlen_GA': ['SOCO'],
#              'Jackson_OK': ['SWPP'],
#              'Iowa_IA': ['MISO'],
#              'Story_IA': ['MISO'],
#              'Lorain_OH': ['PJM'],
#              'Cherokee_GA': ['SOCO'],
#              'Dawson_GA': ['SOCO'],
#              'Fannin_GA': ['SOCO', 'TVA'],
#              'Forsyth_GA': ['SOCO'],
#              'Gilmer_GA': ['SOCO', 'TVA'],
#              'Gordon_GA': ['SOCO', 'TVA'],
#              'Lumpkin_GA': ['SOCO'],
#              'Murray_GA': ['SOCO', 'TVA'],
#              'Pickens_GA': ['SOCO'],
#              'Blount_TN': ['TVA'],
#              'Orange_CA': ['CISO'],
#              'Anchorage_AK': ['AMPL', 'CEA'],
#              'Madison_IN': ['PJM', 'MISO'],
#              'Anoka_MN': ['MISO'],
#              'Chisago_MN': ['MISO'],
#              'Hennepin_MN': ['MISO'],
#              'Isanti_MN': ['MISO'],
#              'Ramsey_MN': ['MISO'],
#              'Sherburne_MN': ['MISO'],
#              'Washington_MN': ['MISO'],
#              'Nelson_KY': ['LGEE', 'PJM'],
#              'Riverside_CA': ['WALC', 'CISO', 'IID', 'WACM', 'SWPP', 'PACW'],
#              'Wake_NC': ['CPLE', 'DUK'],
#              'Grainger_TN': ['TVA'],
#              'Hamblen_TN': ['TVA'],
#              'Jefferson_TN': ['TVA'],
#              'Sevier_TN': ['TVA'],
#              'Albemarle_VA': ['PJM'],
#              'Amherst_VA': ['PJM'],
#              'Appomattox_VA': ['PJM'],
#              'Bedford_VA': ['PJM'],
#              'Bland_VA': ['PJM'],
#              'Botetourt_VA': ['PJM'],
#              'Buchanan_VA': ['PJM'],
#              'Buckingham_VA': ['PJM'],
#              'Campbell_VA': ['PJM'],
#              'Carroll_VA': ['PJM'],
#              'Craig_VA': ['PJM'],
#              'Dickenson_VA': ['PJM', 'LGEE'],
#              'Floyd_VA': ['PJM'],
#              'Fluvanna_VA': ['PJM'],
#              'Franklin_VA': ['PJM'],
#              'Galax City_VA': ['PJM'],
#              'Giles_VA': ['PJM'],
#              'Grayson_VA': ['PJM'],
#              'Henry_VA': ['PJM'],
#              'Lynchburg City_VA': ['PJM'],
#              'Montgomery_VA': ['PJM'],
#              'Nelson_VA': ['PJM'],
#              'Patrick_VA': ['PJM'],
#              'Pittsylvania_VA': ['PJM'],
#              'Pulaski_VA': ['PJM'],
#              'Roanoke_VA': ['PJM'],
#              'Roanoke City_VA': ['PJM'],
#              'Russell_VA': ['PJM', 'LGEE'],
#              'Scott_VA': ['PJM', 'TVA', 'LGEE'],
#              'Smyth_VA': ['PJM'],
#              'Tazewell_VA': ['PJM'],
#              'Washington_VA': ['PJM', 'TVA'],
#              'Wise_VA': ['PJM', 'LGEE', 'TVA'],
#              'Wythe_VA': ['PJM'],
#              'Boone_WV': ['PJM'],
#              'Cabell_WV': ['PJM'],
#              'Clay_WV': ['PJM'],
#              'Fayette_WV': ['PJM'],
#              'Greenbrier_WV': ['PJM'],
#              'Jackson_WV': ['PJM'],
#              'Kanawha_WV': ['PJM'],
#              'Lincoln_WV': ['PJM'],
#              'Logan_WV': ['PJM'],
#              'Mason_WV': ['PJM'],
#              'McDowell_WV': ['PJM'],
#              'Mercer_WV': ['PJM'],
#              'Mingo_WV': ['PJM'],
#              'Monroe_WV': ['PJM'],
#              'Nicholas_WV': ['PJM'],
#              'Putnam_WV': ['PJM'],
#              'Raleigh_WV': ['PJM'],
#              'Roane_WV': ['PJM'],
#              'Summers_WV': ['PJM'],
#              'Wayne_WV': ['PJM'],
#              'Wyoming_WV': ['PJM'],
#              'Apache_AZ': ['AZPS',
#               'PACE',
#               'PNM',
#               'WALC',
#               'WACM',
#               'SWPP',
#               'PACW'],
#              'Cochise_AZ': ['AZPS',
#               'PNM',
#               'WALC',
#               'TEPC',
#               'WACM',
#               'SWPP',
#               'PACW'],
#              'Coconino_AZ': ['AZPS', 'WALC', 'WACM', 'PACE', 'SWPP', 'PACW'],
#              'Gila_AZ': ['AZPS', 'PNM', 'SRP', 'WALC', 'WACM', 'SWPP', 'PACW'],
#              'Graham_AZ': ['AZPS', 'WALC'],
#              'Greenlee_AZ': ['AZPS', 'WALC', 'PNM'],
#              'Maricopa_AZ': ['AZPS', 'WALC', 'SRP', 'WACM', 'SWPP', 'PACW'],
#              'Mohave_AZ': ['AZPS',
#               'WALC',
#               'WACM',
#               'TEPC',
#               'SWPP',
#               'PACW',
#               'PACE'],
#              'Navajo_AZ': ['AZPS',
#               'PACE',
#               'PNM',
#               'WALC',
#               'WACM',
#               'SWPP',
#               'PACW'],
#              'Pinal_AZ': ['AZPS', 'WALC', 'SRP', 'WACM', 'SWPP', 'PACW'],
#              'Santa Cruz_AZ': ['AZPS', 'WALC', 'TEPC'],
#              'Yavapai_AZ': ['AZPS', 'WALC', 'WACM', 'SWPP', 'PACW'],
#              'Yuma_AZ': ['AZPS', 'WALC', 'WACM', 'SWPP', 'PACW'],
#              'Arkansas_AR': ['MISO'],
#              'Ashley_AR': ['MISO'],
#              'Baxter_AR': ['MISO'],
#              'Boone_AR': ['MISO', 'SWPP'],
#              'Bradley_AR': ['MISO'],
#              'Calhoun_AR': ['MISO'],
#              'Carroll_AR': ['MISO', 'SWPP'],
#              'Chicot_AR': ['MISO'],
#              'Clark_AR': ['MISO'],
#              'Clay_AR': ['MISO'],
#              'Cleburne_AR': ['MISO'],
#              'Cleveland_AR': ['MISO'],
#              'Columbia_AR': ['MISO'],
#              'Conway_AR': ['MISO'],
#              'Craighead_AR': ['MISO'],
#              'Crittenden_AR': ['MISO', 'AECI'],
#              'Cross_AR': ['MISO'],
#              'Dallas_AR': ['MISO'],
#              'Desha_AR': ['MISO'],
#              'Drew_AR': ['MISO'],
#              'Faulkner_AR': ['MISO'],
#              'Fulton_AR': ['MISO'],
#              'Garland_AR': ['MISO'],
#              'Grant_AR': ['MISO'],
#              'Greene_AR': ['MISO', 'SPA'],
#              'Hempstead_AR': ['MISO', 'SWPP'],
#              'Hot Spring_AR': ['MISO'],
#              'Independence_AR': ['MISO'],
#              'Izard_AR': ['MISO'],
#              'Jackson_AR': ['MISO'],
#              'Jefferson_AR': ['MISO'],
#              'Johnson_AR': ['MISO', 'SWPP'],
#              'Lafayette_AR': ['MISO', 'SWPP'],
#              'Lawrence_AR': ['MISO'],
#              'Lee_AR': ['MISO'],
#              'Lincoln_AR': ['MISO'],
#              'Logan_AR': ['MISO', 'SWPP'],
#              'Lonoke_AR': ['MISO'],
#              'Marion_AR': ['MISO'],
#              'Miller_AR': ['MISO', 'SWPP'],
#              'Mississippi_AR': ['MISO'],
#              'Monroe_AR': ['MISO'],
#              'Montgomery_AR': ['MISO'],
#              'Nevada_AR': ['MISO'],
#              'Newton_AR': ['MISO', 'SWPP'],
#              'Ouachita_AR': ['MISO'],
#              'Perry_AR': ['MISO'],
#              'Phillips_AR': ['MISO'],
#              'Pike_AR': ['MISO', 'SWPP'],
#              'Poinsett_AR': ['MISO'],
#              'Pope_AR': ['MISO', 'SWPP'],
#              'Prairie_AR': ['MISO'],
#              'Pulaski_AR': ['MISO'],
#              'Randolph_AR': ['MISO'],
#              'Saline_AR': ['MISO'],
#              'Scott_AR': ['MISO', 'SWPP'],
#              'Searcy_AR': ['MISO'],
#              'Sharp_AR': ['MISO'],
#              'St Francis_AR': ['MISO'],
#              'Stone_AR': ['MISO'],
#              'Union_AR': ['MISO'],
#              'Van Buren_AR': ['MISO'],
#              'White_AR': ['MISO'],
#              'Woodruff_AR': ['MISO'],
#              'Yell_AR': ['MISO', 'SWPP'],
#              'Tipton_TN': ['MISO', 'TVA'],
#              'Crawford_AR': ['SWPP'],
#              'Franklin_AR': ['SWPP'],
#              'Madison_AR': ['SWPP'],
#              'Sebastian_AR': ['SWPP'],
#              'Washington_AR': ['SWPP'],
#              'Adair_OK': ['SWPP', 'AECI'],
#              'Le Flore_OK': ['SWPP', 'AECI', 'MISO'],
#              'Sequoyah_OK': ['SWPP', 'AECI'],
#              'Sibley_MN': ['MISO'],
#              'Cook_MN': ['MISO'],
#              'Lake_MN': ['MISO'],
#              'Jackson_OR': ['PACW', 'PACE'],
#              'Pitkin_CO': ['PSCO', 'WALC', 'WACM', 'SWPP', 'PACW'],
#              'Fremont_IA': ['AECI', 'MISO'],
#              'Page_IA': ['AECI', 'MISO'],
#              'Atchison_MO': ['AECI', 'SWPP'],
#              'Holt_MO': ['AECI', 'SWPP'],
#              'Nodaway_MO': ['AECI', 'SWPP', 'WALC', 'WACM', 'PACW'],
#              'Limestone_AL': ['TVA'],
#              'McMinn_TN': ['TVA'],
#              'Atlantic_NJ': ['PJM'],
#              'Burlington_NJ': ['PJM'],
#              'Camden_NJ': ['PJM'],
#              'Cape May_NJ': ['PJM'],
#              'Cumberland_NJ': ['PJM'],
#              'Gloucester_NJ': ['PJM'],
#              'Ocean_NJ': ['PJM'],
#              'Salem_NJ': ['PJM'],
#              'Audubon_IA': ['MISO', 'SWPP', 'WALC', 'WACM', 'PACW'],
#              'Cass_IA': ['MISO', 'SWPP', 'WALC', 'WACM', 'PACW'],
#              'Pottawattamie_IA': ['MISO', 'SWPP', 'WALC', 'WACM', 'PACW'],
#              'Shelby_IA': ['MISO', 'SWPP', 'WALC', 'WACM', 'PACW'],
#              'Johnson_NE': ['SWPP'],
#              'Nemaha_NE': ['SWPP'],
#              'Richardson_NE': ['SWPP'],
#              'DeKalb_IN': ['PJM', 'MISO'],
#              'Butler_KS': ['SWPP'],
#              'Mower_MN': ['MISO'],
#              'Travis_TX': ['ERCO'],
#              'Williamson_TX': ['ERCO'],
#              'Douglas_MO': ['AECI'],
#              'Lafayette_MO': ['AECI', 'SWPP'],
#              'Pitt_NC': ['CPLE', 'PJM'],
#              'Los Angeles_CA': ['CISO', 'LDWP'],
#              'Alleghany_VA': ['PJM'],
#              'Augusta_VA': ['PJM'],
#              'Bath_VA': ['PJM'],
#              'Highland_VA': ['PJM'],
#              'Rockbridge_VA': ['PJM'],
#              'Clearwater_MN': ['MISO'],
#              'Douglas_KS': ['SWPP'],
#              'Anne Arundel_MD': ['PJM'],
#              'Baltimore_MD': ['PJM'],
#              'Baltimore City_MD': ['PJM'],
#              'Calvert_MD': ['PJM'],
#              'Carroll_MD': ['PJM'],
#              'Harford_MD': ['PJM'],
#              'Howard_MD': ['PJM'],
#              'Montgomery_MD': ['PJM'],
#              'Prince Georges_MD': ['PJM'],
#              'Bailey_TX': ['SWPP'],
#              'Castro_TX': ['SWPP'],
#              'Cochran_TX': ['SWPP'],
#              'Lamb_TX': ['SWPP', 'ERCO'],
#              'Parmer_TX': ['SWPP'],
#              'Bandera_TX': ['ERCO'],
#              'Bexar_TX': ['ERCO'],
#              'Kendall_TX': ['ERCO'],
#              'Kerr_TX': ['ERCO'],
#              'Medina_TX': ['ERCO'],
#              'Real_TX': ['ERCO'],
#              'Uvalde_TX': ['ERCO', 'EPE'],
#              'Coos_OR': ['BPAT', 'PACW', 'PACE'],
#              'Curry_OR': ['BPAT'],
#              'Aroostook_ME': ['NBSO', 'ISNE'],
#              'Hancock_ME': ['NBSO', 'ISNE'],
#              'Penobscot_ME': ['NBSO', 'ISNE'],
#              'Piscataquis_ME': ['NBSO', 'ISNE'],
#              'Waldo_ME': ['NBSO', 'ISNE'],
#              'Washington_ME': ['NBSO', 'ISNE'],
#              'La Crosse_WI': ['MISO'],
#              'Monroe_WI': ['MISO'],
#              'Baraga_MI': ['MISO'],
#              'Knox_KY': ['LGEE', 'PJM'],
#              'Clay_MN': ['MISO', 'SWPP', 'WALC', 'WACM', 'PACW'],
#              'Barron_WI': ['MISO'],
#              'Burnett_WI': ['MISO'],
#              'Chippewa_WI': ['MISO'],
#              'Dunn_WI': ['MISO'],
#              'Polk_WI': ['MISO'],
#              'Rusk_WI': ['MISO'],
#              'Sawyer_WI': ['MISO'],
#              'Washburn_WI': ['MISO'],
#              'Bell_TX': ['ERCO'],
#              'Burleson_TX': ['ERCO', 'MISO'],
#              'Lee_TX': ['ERCO'],
#              'Milam_TX': ['ERCO', 'MISO'],
#              'Barry_MO': ['AECI', 'SWPP'],
#              'McDonald_MO': ['AECI', 'SWPP'],
#              'Bartholomew_IN': ['MISO'],
#              'Decatur_IN': ['MISO'],
#              'Jackson_IN': ['MISO'],
#              'Jennings_IN': ['MISO'],
#              'Polk_FL': ['FPC', 'FMPP', 'SEC', 'TEC'],
#              'Barton_MO': ['AECI', 'SWPP'],
#              'Cedar_MO': ['AECI', 'SWPP'],
#              'Dade_MO': ['AECI', 'SWPP'],
#              'Jasper_MO': ['AECI', 'SPA', 'SWPP'],
#              'Vernon_MO': ['AECI', 'SWPP'],
#              'Mercer_ND': ['SWPP', 'WACM', 'WALC', 'PACW'],
#              'Park_WY': ['SWPP', 'WACM', 'NWMT', 'PACW', 'PACE', 'WALC'],
#              'Kane_IL': ['PJM'],
#              'Bay_MI': ['MISO'],
#              'Gogebic_MI': ['MISO'],
#              'Ashland_WI': ['MISO'],
#              'Bayfield_WI': ['MISO'],
#              'Douglas_WI': ['MISO'],
#              'Iron_WI': ['MISO'],
#              'Vilas_WI': ['MISO'],
#              'Carbon_MT': ['NWMT',
#               'WACM',
#               'BPAT',
#               'WAUW',
#               'WALC',
#               'SWPP',
#               'PACW'],
#              'Stillwater_MT': ['NWMT', 'WAUW'],
#              'Sweet Grass_MT': ['NWMT', 'WAUW'],
#              'Gage_NE': ['SWPP'],
#              'Allen_LA': ['MISO'],
#              'Beauregard_LA': ['MISO'],
#              'Calcasieu_LA': ['MISO'],
#              'Evangeline_LA': ['MISO'],
#              'Jefferson Davis_LA': ['MISO'],
#              'Vernon_LA': ['MISO', 'SWPP'],
#              'Middlesex_MA': ['ISNE'],
#              'Mitchell_KS': ['SWPP'],
#              'Beltrami_MN': ['MISO'],
#              'Cass_MN': ['MISO'],
#              'Hubbard_MN': ['MISO'],
#              'Itasca_MN': ['MISO'],
#              'Koochiching_MN': ['MISO'],
#              'Marlboro_SC': ['SC', 'CPLE'],
#              'Benton_TN': ['TVA'],
#              'Benton_WA': ['BPAT', 'PACW', 'PACE'],
#              'Marshall_KY': ['TVA', 'MISO'],
#              'Benton_AR': ['SWPP'],
#              'Borden_TX': ['ERCO', 'SWPP'],
#              'Fisher_TX': ['ERCO'],
#              'Garza_TX': ['ERCO', 'SWPP'],
#              'Haskell_TX': ['ERCO'],
#              'Jones_TX': ['ERCO'],
#              'Kent_TX': ['ERCO'],
#              'Mitchell_TX': ['ERCO'],
#              'Nolan_TX': ['ERCO'],
#              'Scurry_TX': ['ERCO'],
#              'Shackelford_TX': ['ERCO'],
#              'Stonewall_TX': ['ERCO'],
#              'Throckmorton_TX': ['ERCO'],
#              'Lincoln_SD': ['SWPP', 'MISO', 'WALC', 'WACM', 'PACW'],
#              'Union_SD': ['SWPP', 'MISO', 'WALC', 'WACM', 'PACW'],
#              'Berkeley_SC': ['SC', 'SCEG'],
#              'Charleston_SC': ['SC', 'SCEG'],
#              'Dorchester_SC': ['SC', 'SCEG'],
#              'Lewis_WA': ['BPAT', 'TPWR'],
#              'Yakima_WA': ['BPAT', 'PACW', 'PACE'],
#              'Big Horn_MT': ['WACM',
#               'BPAT',
#               'WAUW',
#               'NWMT',
#               'WALC',
#               'SWPP',
#               'PACW'],
#              'Big Horn_WY': ['WACM', 'PACW', 'PACE', 'WALC', 'SWPP'],
#              'Johnson_WY': ['WACM', 'SWPP', 'PACW', 'PACE'],
#              'Sheridan_WY': ['WACM', 'BPAT', 'SWPP'],
#              'Washakie_WY': ['WACM', 'PACW', 'PACE', 'WALC', 'SWPP'],
#              'Breathitt_KY': ['PJM'],
#              'Floyd_KY': ['PJM'],
#              'Johnson_KY': ['PJM'],
#              'Knott_KY': ['PJM'],
#              'Lawrence_KY': ['PJM'],
#              'Magoffin_KY': ['PJM'],
#              'Martin_KY': ['PJM'],
#              'Morgan_KY': ['PJM'],
#              'Adams_WA': ['BPAT', 'GCPD', 'AVA'],
#              'Franklin_WA': ['BPAT'],
#              'Grant_WA': ['BPAT', 'GCPD', 'AVA'],
#              'Lincoln_WA': ['BPAT', 'GCPD', 'AVA'],
#              'Whitman_WA': ['BPAT', 'AVA'],
#              'Lane_OR': ['BPAT', 'PACW', 'PACE'],
#              'Clarendon_SC': ['SC', 'CPLE'],
#              'Kershaw_SC': ['SC', 'CPLE', 'DUK', 'SCEG'],
#              'Lee_SC': ['SC', 'CPLE', 'SCEG'],
#              'Sumter_SC': ['SC', 'CPLE'],
#              'Custer_SD': ['SWPP', 'WACM', 'WALC', 'PACW'],
#              'Fall River_SD': ['SWPP', 'WACM', 'WALC', 'PACW'],
#              'Lawrence_SD': ['SWPP', 'WACM'],
#              'Meade_SD': ['SWPP', 'WACM', 'WALC', 'PACW'],
#              'Pennington_SD': ['SWPP', 'WACM', 'WALC', 'PACW'],
#              'Shannon_SD': ['SWPP', 'WACM'],
#              'Bollinger_MO': ['AECI', 'MISO'],
#              'Cape Girardeau_MO': ['AECI', 'MISO'],
#              'Dent_MO': ['AECI'],
#              'Iron_MO': ['AECI', 'MISO'],
#              'Madison_MO': ['AECI', 'MISO'],
#              'Reynolds_MO': ['AECI', 'MISO'],
#              'Shannon_MO': ['AECI'],
#              'Wayne_MO': ['AECI'],
#              'Jackson_WI': ['MISO'],
#              'Whatcom_WA': ['PSEI', 'BPAT'],
#              'Davis_IA': ['AECI', 'MISO'],
#              'Faribault_MN': ['MISO'],
#              'Blue Earth_MN': ['MISO'],
#              'Le Sueur_MN': ['MISO'],
#              'Nicollet_MN': ['MISO'],
#              'Anderson_KY': ['PJM', 'LGEE'],
#              'Bourbon_KY': ['PJM', 'LGEE'],
#              'Bracken_KY': ['PJM', 'LGEE'],
#              'Fayette_KY': ['PJM', 'LGEE'],
#              'Franklin_KY': ['PJM', 'LGEE'],
#              'Garrard_KY': ['PJM', 'LGEE'],
#              'Grant_KY': ['PJM', 'LGEE', 'TVA'],
#              'Harrison_KY': ['PJM', 'LGEE'],
#              'Henry_KY': ['PJM', 'LGEE'],
#              'Jackson_KY': ['PJM'],
#              'Jessamine_KY': ['PJM', 'LGEE'],
#              'Madison_KY': ['PJM', 'LGEE'],
#              'Mercer_KY': ['PJM', 'LGEE'],
#              'Nicholas_KY': ['PJM', 'LGEE'],
#              'Pendleton_KY': ['PJM', 'LGEE'],
#              'Robertson_KY': ['PJM', 'LGEE'],
#              'Scott_KY': ['PJM', 'LGEE'],
#              'Shelby_KY': ['PJM', 'LGEE'],
#              'Spencer_KY': ['PJM', 'LGEE'],
#              'Washington_KY': ['PJM', 'LGEE'],
#              'Woodford_KY': ['PJM', 'LGEE'],
#              'Alexander_NC': ['DUK'],
#              'Alleghany_NC': ['DUK'],
#              'Ashe_NC': ['DUK'],
#              'Avery_NC': ['DUK', 'CPLE', 'TVA'],
#              'Caldwell_NC': ['DUK'],
#              'Watauga_NC': ['DUK', 'TVA'],
#              'Wilkes_NC': ['DUK'],
#              'Anderson_SC': ['DUK'],
#              'Greenville_SC': ['DUK'],
#              'Oconee_SC': ['DUK'],
#              'Pickens_SC': ['DUK'],
#              'Spartanburg_SC': ['DUK'],
#              'Towns_GA': ['TVA'],
#              'Union_GA': ['TVA'],
#              'Cherokee_NC': ['TVA', 'DUK'],
#              'Austin_TX': ['ERCO'],
#              'Bastrop_TX': ['ERCO'],
#              'Caldwell_TX': ['ERCO'],
#              'Colorado_TX': ['ERCO'],
#              'Fayette_TX': ['ERCO'],
#              'Gonzales_TX': ['ERCO'],
#              'Guadalupe_TX': ['ERCO'],
#              'Hays_TX': ['ERCO'],
#              'Washington_TX': ['ERCO', 'MISO'],
#              'Wells_IN': ['PJM', 'MISO'],
#              'Bon Homme_SD': ['SWPP', 'WALC', 'WACM', 'PACW'],
#              'Yankton_SD': ['SWPP', 'WALC', 'WACM', 'PACW'],
#              'Fayette_TN': ['TVA'],
#              'Hardeman_TN': ['TVA'],
#              'Grant_WI': ['MISO'],
#              'Audrain_MO': ['AECI', 'MISO'],
#              'Boone_MO': ['AECI', 'MISO'],
#              'Callaway_MO': ['AECI', 'MISO'],
#              'Howard_MO': ['AECI', 'SWPP', 'MISO'],
#              'Monroe_MO': ['AECI', 'MISO'],
#              'Randolph_MO': ['AECI', 'SWPP', 'MISO'],
#              'Clark_NV': ['WALC', 'NEVP', 'WACM', 'SWPP', 'PACW'],
#              'Davis_UT': ['PACE', 'PACW'],
#              'Bowie_TX': ['SWPP', 'MISO'],
#              'Cass_TX': ['SWPP'],
#              'Franklin_TX': ['SWPP', 'ERCO'],
#              'Morris_TX': ['SWPP'],
#              'Red River_TX': ['SWPP', 'ERCO'],
#              'Titus_TX': ['SWPP'],
#              'Wood_OH': ['PJM'],
#              'Warren_KY': ['TVA'],
#              'New London_CT': ['ISNE'],
#              'Crow Wing_MN': ['MISO'],
#              'Norfolk_MA': ['ISNE'],
#              'Wilkin_MN': ['MISO', 'SWPP', 'WALC', 'WACM', 'PACW'],
#              'Marshall_IN': ['MISO', 'PJM'],
#              'Cleveland_NC': ['DUK'],
#              'Polk_NC': ['DUK'],
#              'Rutherford_NC': ['DUK', 'CPLE'],
#              'Cherokee_SC': ['DUK'],
#              'Newberry_SC': ['DUK', 'SC', 'SCEG'],
#              'Union_SC': ['DUK', 'SCEG'],
#              'York_SC': ['DUK', 'SC'],
#              'Daggett_UT': ['WACM', 'WALC', 'SWPP', 'PACW'],
#              'Summit_UT': ['WACM', 'PACW', 'PACE'],
#              'Lincoln_WY': ['WACM', 'BPAT', 'PACW', 'PACE', 'WALC', 'SWPP'],
#              'Sweetwater_WY': ['WACM', 'PACW', 'PACE', 'WALC', 'SWPP'],
#              'Uinta_WY': ['WACM', 'PACW', 'PACE'],
#              'Box Elder_UT': ['PACE', 'PACW', 'BPAT'],
#              'Sullivan_TN': ['TVA', 'PJM'],
#              'Bristol City_VA': ['TVA'],
#              'Green_WI': ['MISO'],
#              'Custer_NE': ['SWPP'],
#              'Brookings_SD': ['WACM', 'SWPP', 'MISO', 'WALC', 'PACW'],
#              'Brown_MN': ['MISO'],
#              'Cottonwood_MN': ['MISO'],
#              'Redwood_MN': ['MISO'],
#              'Renville_MN': ['MISO'],
#              'Watonwan_MN': ['MISO'],
#              'Atchison_KS': ['SWPP'],
#              'Brown_KS': ['SWPP'],
#              'Doniphan_KS': ['SWPP'],
#              'Jackson_KS': ['SWPP'],
#              'Jefferson_KS': ['SWPP'],
#              'Nemaha_KS': ['SWPP'],
#              'Burke_ND': ['SWPP', 'WACM'],
#              'Divide_ND': ['SWPP', 'WACM'],
#              'Mountrail_ND': ['SWPP', 'MISO', 'WACM'],
#              'Renville_ND': ['SWPP', 'WACM', 'MISO'],
#              'Ward_ND': ['SWPP', 'MISO', 'WACM', 'WALC', 'PACW'],
#              'Williams_ND': ['SWPP', 'WAUW', 'WACM', 'WALC', 'PACW'],
#              'Cameron_TX': ['ERCO'],
#              'Haywood_TN': ['TVA'],
#              'Defiance_OH': ['PJM'],
#              'Williams_OH': ['PJM'],
#              'Brazos_TX': ['ERCO', 'MISO'],
#              'Robertson_TX': ['ERCO', 'MISO'],
#              'Wright_MN': ['MISO'],
#              'Gwinnett_GA': ['SOCO'],
#              'Hall_GA': ['SOCO'],
#              'Athens_OH': ['PJM'],
#              'Gallia_OH': ['PJM'],
#              'Jackson_OH': ['PJM'],
#              'Lawrence_OH': ['PJM'],
#              'Meigs_OH': ['PJM'],
#              'Ross_OH': ['PJM'],
#              'Vinton_OH': ['PJM'],
#              'Cassia_ID': ['BPAT', 'IPCO'],
#              'Minidoka_ID': ['BPAT', 'IPCO'],
#              'Chittenden_VT': ['ISNE'],
#              'Coffey_KS': ['SWPP'],
#              'Burt_NE': ['SWPP'],
#              'Colfax_NE': ['SWPP', 'WACM'],
#              'Cuming_NE': ['SWPP'],
#              'Dodge_NE': ['SWPP'],
#              'Thurston_NE': ['SWPP'],
#              'Washington_NE': ['SWPP'],
#              'Chase_KS': ['SWPP'],
#              'Cowley_KS': ['SWPP'],
#              'Greenwood_KS': ['SWPP'],
#              'Harvey_KS': ['SWPP'],
#              'Marion_KS': ['SWPP'],
#              'Sedgwick_KS': ['SWPP'],
#              'Butler_NE': ['SWPP'],
#              'Saunders_NE': ['SWPP'],
#              'Morris_NJ': ['PJM'],
#              'Passaic_NJ': ['PJM', 'NYIS'],
#              'Franklin_IN': ['PJM', 'MISO'],
#              'Butler_OH': ['PJM'],
#              'Hamilton_OH': ['PJM'],
#              'Montgomery_OH': ['PJM'],
#              'Preble_OH': ['PJM'],
#              'Butler_IA': ['SWPP', 'MISO'],
#              'Cerro Gordo_IA': ['SWPP', 'MISO'],
#              'Floyd_IA': ['SWPP', 'MISO'],
#              'Franklin_IA': ['SWPP', 'MISO'],
#              'Butte_SD': ['WACM', 'SWPP', 'WALC', 'PACW'],
#              'Grady_GA': ['SOCO'],
#              'Clark_KS': ['SWPP'],
#              'Comanche_KS': ['SWPP'],
#              'Ford_KS': ['SWPP'],
#              'Gray_KS': ['SWPP'],
#              'Haskell_KS': ['SWPP'],
#              'Kiowa_KS': ['SWPP'],
#              'Meade_KS': ['SWPP'],
#              'Seward_KS': ['SWPP'],
#              'Stevens_KS': ['SWPP'],
#              'Attala_MS': ['TVA', 'MISO'],
#              'Leake_MS': ['TVA', 'MISO', 'SOCO'],
#              'Newton_MS': ['TVA', 'SOCO', 'MISO'],
#              'Rankin_MS': ['TVA', 'MISO'],
#              'Scott_MS': ['TVA', 'MISO', 'SOCO'],
#              'Tate_MS': ['TVA', 'MISO'],
#              'Furnas_NE': ['SWPP'],
#              'Clinton_MO': ['AECI', 'SWPP', 'MISO'],
#              'DeKalb_MO': ['AECI', 'SWPP', 'MISO'],
#              'Bryan_GA': ['SOCO'],
#              'Bulloch_GA': ['SOCO'],
#              'Chatham_GA': ['SOCO'],
#              'Evans_GA': ['SOCO'],
#              'Liberty_GA': ['SOCO'],
#              'Long_GA': ['SOCO'],
#              'Mitchell_GA': ['SOCO'],
#              'Cleveland_OK': ['SWPP'],
#              'Creek_OK': ['SWPP', 'AECI'],
#              'Hughes_OK': ['SWPP'],
#              'Lincoln_OK': ['SWPP', 'AECI'],
#              'McIntosh_OK': ['SWPP', 'AECI'],
#              'Okfuskee_OK': ['SWPP', 'AECI'],
#              'Oklahoma_OK': ['SWPP', 'AECI'],
#              'Okmulgee_OK': ['SWPP', 'AECI'],
#              'Pottawatomie_OK': ['SWPP'],
#              'Seminole_OK': ['SWPP', 'AECI'],
#              'Clackamas_OR': ['PGE'],
#              'Cannon_TN': ['TVA'],
#              'Coffee_TN': ['TVA'],
#              'DeKalb_TN': ['TVA'],
#              'Grundy_TN': ['TVA'],
#              'Putnam_TN': ['TVA'],
#              'Van Buren_TN': ['TVA'],
#              'Warren_TN': ['TVA'],
#              'White_TN': ['TVA'],
#              'Chautauqua_KS': ['SWPP'],
#              'Elk_KS': ['SWPP'],
#              'Montgomery_KS': ['SWPP'],
#              'Madison_MS': ['MISO'],
#              'Dare_NC': ['PJM'],
#              'Burleigh_ND': ['SWPP', 'WACM', 'MISO', 'WALC', 'PACW'],
#              'Emmons_ND': ['SWPP', 'WACM', 'WALC', 'PACW'],
#              'Kidder_ND': ['SWPP', 'WACM', 'MISO', 'WALC', 'PACW'],
#              'McLean_ND': ['SWPP', 'MISO', 'WALC', 'WACM', 'PACW'],
#              'Sheridan_ND': ['SWPP', 'MISO'],
#              'Campbell_SD': ['SWPP', 'WACM', 'WALC', 'PACW'],
#              'Potter_SD': ['SWPP', 'WACM', 'WALC', 'PACW'],
#              'Walworth_SD': ['SWPP', 'WACM', 'WALC', 'PACW'],
#              'Albany_WY': ['WACM', 'PACW', 'PACE', 'WALC', 'SWPP'],
#              'Carbon_WY': ['WACM', 'PACW', 'PACE', 'PSCO', 'WALC', 'SWPP'],
#              'Alamance_NC': ['CPLE', 'DUK'],
#              'Anson_NC': ['CPLE', 'DUK'],
#              'Beaufort_NC': ['CPLE', 'PJM'],
#              'Bladen_NC': ['CPLE'],
#              'Brunswick_NC': ['CPLE'],
#              'Buncombe_NC': ['CPLE', 'DUK'],
#              'Carteret_NC': ['CPLE'],
#              'Caswell_NC': ['CPLE', 'DUK'],
#              'Chatham_NC': ['CPLE', 'DUK'],
#              'Columbus_NC': ['CPLE'],
#              'Craven_NC': ['CPLE', 'PJM'],
#              'Cumberland_NC': ['CPLE'],
#              'Duplin_NC': ['CPLE'],
#              'Durham_NC': ['CPLE', 'DUK'],
#              'Edgecombe_NC': ['CPLE', 'PJM'],
#              'Franklin_NC': ['CPLE'],
#              'Granville_NC': ['CPLE', 'DUK', 'PJM'],
#              'Greene_NC': ['CPLE'],
#              'Guilford_NC': ['CPLE', 'DUK'],
#              'Halifax_NC': ['CPLE', 'PJM'],
#              'Harnett_NC': ['CPLE'],
#              'Haywood_NC': ['CPLE', 'DUK'],
#              'Henderson_NC': ['CPLE', 'DUK'],
#              'Hoke_NC': ['CPLE'],
#              'Jackson_NC': ['CPLE', 'DUK'],
#              'Johnston_NC': ['CPLE'],
#              'Jones_NC': ['CPLE'],
#              'Lee_NC': ['CPLE'],
#              'Lenoir_NC': ['CPLE'],
#              'Madison_NC': ['CPLE', 'DUK'],
#              'McDowell_NC': ['CPLE', 'DUK'],
#              'Mitchell_NC': ['CPLE', 'DUK'],
#              'Montgomery_NC': ['CPLE', 'DUK'],
#              'Moore_NC': ['CPLE'],
#              'Nash_NC': ['CPLE', 'PJM'],
#              'New Hanover_NC': ['CPLE'],
#              'Onslow_NC': ['CPLE'],
#              'Orange_NC': ['CPLE', 'DUK'],
#              'Pamlico_NC': ['CPLE', 'PJM'],
#              'Pender_NC': ['CPLE'],
#              'Person_NC': ['CPLE', 'DUK', 'PJM'],
#              'Randolph_NC': ['CPLE', 'DUK'],
#              'Richmond_NC': ['CPLE'],
#              'Robeson_NC': ['CPLE'],
#              'Sampson_NC': ['CPLE'],
#              'Scotland_NC': ['CPLE'],
#              'Vance_NC': ['CPLE', 'PJM'],
#              'Warren_NC': ['CPLE', 'PJM'],
#              'Wayne_NC': ['CPLE'],
#              'Wilson_NC': ['CPLE', 'PJM'],
#              'Yancey_NC': ['CPLE'],
#              'Chesterfield_SC': ['CPLE', 'SC'],
#              'Darlington_SC': ['CPLE', 'SC'],
#              'Dillon_SC': ['CPLE', 'SC'],
#              'Florence_SC': ['CPLE', 'SC'],
#              'Georgetown_SC': ['CPLE', 'SC'],
#              'Horry_SC': ['CPLE', 'SC'],
#              'Marion_SC': ['CPLE', 'SC'],
#              'Williamsburg_SC': ['CPLE', 'SC'],
#              'Carroll_TN': ['TVA'],
#              'Henderson_TN': ['TVA'],
#              'Weakley_TN': ['TVA'],
#              'Carroll_OH': ['PJM'],
#              'Columbiana_OH': ['PJM'],
#              'Harrison_OH': ['PJM'],
#              'Jefferson_OH': ['PJM'],
#              'Stark_OH': ['PJM'],
#              'Tuscarawas_OH': ['PJM'],
#              'Carroll_GA': ['SOCO'],
#              'Floyd_GA': ['SOCO', 'TVA'],
#              'Haralson_GA': ['SOCO'],
#              'Heard_GA': ['SOCO'],
#              'Paulding_GA': ['SOCO'],
#              'Polk_GA': ['SOCO'],
#              'Troup_GA': ['SOCO'],
#              'Stone_MO': ['SWPP', 'AECI'],
#              'Taney_MO': ['SWPP', 'AECI'],
#              'Black Hawk_IA': ['MISO'],
#              'Grundy_IA': ['MISO'],
#              'Cedar_NE': ['SWPP', 'WALC', 'WACM', 'PACW'],
#              'Dixon_NE': ['SWPP'],
#              'Knox_NE': ['SWPP'],
#              'Pierce_NE': ['SWPP'],
#              'Wayne_NE': ['SWPP'],
#              'Ozaukee_WI': ['MISO'],
#              'Auglaize_OH': ['PJM'],
#              'Mercer_OH': ['PJM'],
#              'Logan_OK': ['AECI', 'SWPP'],
#              'Noble_OK': ['AECI', 'SWPP'],
#              'Pawnee_OK': ['AECI', 'SWPP'],
#              'Payne_OK': ['AECI', 'SWPP'],
#              'Merrick_NE': ['SWPP', 'WALC', 'WACM', 'PACW'],
#              'Aurora_SD': ['WACM', 'SWPP', 'WALC', 'PACW'],
#              'Brule_SD': ['WACM', 'SWPP', 'WALC', 'PACW'],
#              'Buffalo_SD': ['WACM', 'WALC', 'SWPP', 'PACW'],
#              'Davison_SD': ['WACM', 'SWPP', 'WALC', 'PACW'],
#              'Hanson_SD': ['WACM', 'MISO', 'SWPP', 'WALC', 'PACW'],
#              'Jerauld_SD': ['WACM', 'SWPP', 'WALC', 'PACW'],
#              'Miner_SD': ['WACM', 'MISO', 'SWPP'],
#              'Sanborn_SD': ['WACM', 'MISO', 'SWPP', 'WALC', 'PACW'],
#              'Crook_OR': ['BPAT', 'PACW', 'PACE'],
#              'Deschutes_OR': ['BPAT', 'PACW', 'PACE'],
#              'Grant_OR': ['BPAT', 'IPCO'],
#              'Jefferson_OR': ['BPAT', 'PACW', 'PACE'],
#              'Linn_OR': ['BPAT', 'PACW', 'PACE'],
#              'Wasco_OR': ['BPAT', 'PACW', 'PACE'],
#              'Dixie_FL': ['SEC', 'FPC'],
#              'Gilchrist_FL': ['SEC', 'FPC'],
#              'Lafayette_FL': ['SEC', 'FPC'],
#              'Levy_FL': ['SEC', 'FPC'],
#              'Marion_FL': ['SEC', 'FPC', 'FMPP'],
#              'Bibb_GA': ['SOCO'],
#              'Butts_GA': ['SOCO'],
#              'Clayton_GA': ['SOCO'],
#              'Fayette_GA': ['SOCO'],
#              'Henry_GA': ['SOCO'],
#              'Jasper_GA': ['SOCO'],
#              'Jones_GA': ['SOCO'],
#              'Lamar_GA': ['SOCO'],
#              'Monroe_GA': ['SOCO'],
#              'Morgan_GA': ['SOCO'],
#              'Newton_GA': ['SOCO'],
#              'Pike_GA': ['SOCO'],
#              'Putnam_GA': ['SOCO'],
#              'Spalding_GA': ['SOCO'],
#              'Albany_NY': ['NYIS'],
#              'Columbia_NY': ['NYIS'],
#              'Dutchess_NY': ['NYIS'],
#              'Greene_NY': ['NYIS'],
#              'Orange_NY': ['NYIS'],
#              'Putnam_NY': ['NYIS'],
#              'Ulster_NY': ['NYIS'],
#              'Douglas_OR': ['BPAT', 'PACW', 'PACE'],
#              'Lincoln_OR': ['BPAT', 'PACW', 'PACE'],
#              'Acadia_LA': ['MISO'],
#              'Avoyelles_LA': ['MISO'],
#              'Catahoula_LA': ['MISO'],
#              'DeSoto_LA': ['MISO', 'SWPP'],
#              'Grant_LA': ['MISO', 'SWPP'],
#              'Iberia_LA': ['MISO'],
#              'La Salle_LA': ['MISO'],
#              'Natchitoches_LA': ['MISO', 'SWPP'],
#              'Pointe Coupee_LA': ['MISO'],
#              'Red River_LA': ['MISO', 'SWPP'],
#              'Sabine_LA': ['MISO', 'SWPP'],
#              'St Landry_LA': ['MISO'],
#              'St Martin_LA': ['MISO'],
#              'St Mary_LA': ['MISO'],
#              'St Tammany_LA': ['MISO'],
#              'Washington_LA': ['MISO'],
#              'Androscoggin_ME': ['ISNE'],
#              'Cumberland_ME': ['ISNE'],
#              'Franklin_ME': ['ISNE'],
#              'Kennebec_ME': ['ISNE'],
#              'Knox_ME': ['ISNE'],
#              'Lincoln_ME': ['ISNE'],
#              'Oxford_ME': ['ISNE'],
#              'Sagadahoc_ME': ['ISNE'],
#              'Somerset_ME': ['ISNE'],
#              'York_ME': ['ISNE'],
#              'Benton_MO': ['AECI', 'SWPP'],
#              'Pettis_MO': ['AECI', 'SWPP', 'MISO'],
#              'Saline_MO': ['AECI', 'SWPP', 'MISO'],
#              'Bernalillo_NM': ['PNM'],
#              'Chaves_NM': ['PNM', 'SWPP'],
#              'De Baca_NM': ['PNM', 'SWPP'],
#              'Guadalupe_NM': ['PNM', 'SWPP'],
#              'Lincoln_NM': ['PNM'],
#              'San Miguel_NM': ['PNM', 'SWPP'],
#              'Sandoval_NM': ['PNM', 'WALC'],
#              'Santa Fe_NM': ['PNM', 'WALC'],
#              'Socorro_NM': ['PNM'],
#              'Torrance_NM': ['PNM'],
#              'Valencia_NM': ['PNM'],
#              'Blanco_TX': ['ERCO'],
#              'Gillespie_TX': ['ERCO'],
#              'Kimble_TX': ['ERCO'],
#              'Llano_TX': ['ERCO'],
#              'Mason_TX': ['ERCO'],
#              'McCulloch_TX': ['ERCO'],
#              'Menard_TX': ['ERCO'],
#              'San Saba_TX': ['ERCO'],
#              'Eddy_NM': ['SWPP', 'EPE', 'ERCO'],
#              'Lea_NM': ['SWPP'],
#              'Otero_NM': ['SWPP', 'EPE', 'PNM', 'ERCO'],
#              'Cumberland_VA': ['PJM'],
#              'Goochland_VA': ['PJM'],
#              'Greene_VA': ['PJM'],
#              'Louisa_VA': ['PJM'],
#              'Orange_VA': ['PJM'],
#              'Prince Edward_VA': ['PJM'],
#              'Marathon_WI': ['MISO'],
#              'Shawano_WI': ['MISO'],
#              'Appanoose_IA': ['AECI', 'MISO'],
#              'Lucas_IA': ['AECI', 'MISO'],
#              'Marion_IA': ['AECI', 'MISO'],
#              'Monroe_IA': ['AECI', 'MISO'],
#              'Wapello_IA': ['AECI', 'MISO'],
#              'Wayne_IA': ['AECI', 'MISO'],
#              'Charles Mix_SD': ['SWPP', 'WALC', 'WACM', 'PACW'],
#              'Douglas_SD': ['SWPP', 'WALC', 'WACM', 'PACW'],
#              'Franklin_PA': ['PJM'],
#              'Neosho_KS': ['SWPP'],
#              'Carver_MN': ['MISO'],
#              'Catoosa_GA': ['TVA', 'SOCO'],
#              'Dade_GA': ['TVA', 'SOCO'],
#              'Walker_GA': ['TVA', 'SOCO'],
#              'Bledsoe_TN': ['TVA'],
#              'Bradley_TN': ['TVA'],
#              'Hamilton_TN': ['TVA'],
#              'Marion_TN': ['TVA'],
#              'Rhea_TN': ['TVA'],
#              'Sequatchie_TN': ['TVA'],
#              'Chelan_WA': ['CHPD'],
#              'King_WA': ['CHPD', 'PSEI', 'SCL', 'TPWR'],
#              'Kittitas_WA': ['CHPD', 'BPAT', 'GCPD', 'PSEI'],
#              'Okanogan_WA': ['CHPD', 'BPAT', 'DOPD'],
#              'Spokane_WA': ['AVA', 'BPAT'],
#              'DeKalb_AL': ['TVA'],
#              'Cherry_NE': ['SWPP', 'WACM'],
#              'Keya Paha_NE': ['SWPP'],
#              'Mellette_SD': ['SWPP', 'WACM'],
#              'Todd_SD': ['SWPP', 'WACM', 'WALC', 'PACW'],
#              'Benzie_MI': ['MISO'],
#              'Grand Traverse_MI': ['MISO'],
#              'Kalkaska_MI': ['MISO'],
#              'Leelanau_MI': ['MISO'],
#              'Manistee_MI': ['MISO'],
#              'Wexford_MI': ['MISO'],
#              'Laramie_WY': ['WACM', 'WALC', 'SWPP', 'PACW'],
#              'Cherokee_TX': ['ERCO'],
#              'Nacogdoches_TX': ['ERCO', 'MISO', 'SWPP'],
#              'Rusk_TX': ['ERCO', 'MISO', 'SWPP'],
#              'Smith_TX': ['ERCO', 'SWPP'],
#              'Hampden_MA': ['ISNE'],
#              'Blaine_OK': ['SWPP'],
#              'Canadian_OK': ['SWPP'],
#              'Custer_OK': ['SWPP'],
#              'Dewey_OK': ['SWPP'],
#              'Kingfisher_OK': ['SWPP'],
#              'Livingston_MO': ['SWPP', 'AECI', 'MISO'],
#              'Banner_NE': ['WACM', 'WALC', 'SWPP', 'PACW'],
#              'Scotts Bluff_NE': ['WACM', 'SWPP', 'WALC', 'PACW'],
#              'Sioux_NE': ['WACM', 'SWPP', 'WALC', 'PACW'],
#              'Taylor_WI': ['MISO'],
#              'Holmes_FL': ['AEC', 'SOCO'],
#              'Okaloosa_FL': ['AEC', 'SOCO'],
#              'Santa Rosa_FL': ['AEC', 'SOCO'],
#              'Walton_FL': ['AEC', 'SOCO'],
#              'Caroline_MD': ['PJM'],
#              'Cecil_MD': ['PJM'],
#              'Dorchester_MD': ['PJM'],
#              'Kent_MD': ['PJM'],
#              'Queen Annes_MD': ['PJM'],
#              'Talbot_MD': ['PJM'],
#              'Wicomico_MD': ['PJM'],
#              'Worcester_MD': ['PJM'],
#              'Kenai Peninsula_AK': ['CEA'],
#              'Atoka_OK': ['SWPP', 'AECI'],
#              'Bryan_OK': ['SWPP'],
#              'Choctaw_OK': ['SWPP'],
#              'McCurtain_OK': ['SWPP', 'MISO'],
#              ...})

# %% [markdown]
# # Find the county that a specific bus belongs to

# %%
from powersimdata.input.grid import Grid
# eastern = Grid(['Eastern'])
western = Grid(['Western'])
# Out:
# --> Loading Eastern interconnect
# Loading zone
# Loading sub
# Loading bus2sub
# Loading bus
# Loading plant
# Loading plant cost
# Loading branch
# Loading DC line
# --> Loading Western interconnect
# Loading zone
# Loading sub
# Loading bus2sub
# Loading bus
# Loading plant
# Loading plant cost
# Loading branch
# Loading DC line

# %%
western.bus.head()
# Out:
#          type     Pd    Qd  Gs   Bs  zone_id        Vm         Va  baseKV  \
# bus_id
# 2010001     1   9.64  2.54   0  0.0      201  1.011472 -38.170877   138.0
# 2010002     1  15.98  6.04   0  0.0      201  1.016888 -35.366581   138.0
# 2010003     1  14.39  1.09   0  0.0      201  1.031361 -32.359590   138.0
# 2010004     1   0.00  0.00   0  0.0      201  1.032374 -32.246548   138.0
# 2010005     1  10.45  2.75   0  0.0      201  1.032323 -32.252838   138.0
#
#          Vmax  Vmin  lam_P  lam_Q  mu_Vmax  mu_Vmin interconnect        lat  \
# bus_id
# 2010001   1.1   0.9    0.0    0.0      0.0      0.0      Western  48.241400
# 2010002   1.1   0.9    0.0    0.0      0.0      0.0      Western  47.695555
# 2010003   1.1   0.9    0.0    0.0      0.0      0.0      Western  47.040041
# 2010004   1.1   0.9    0.0    0.0      0.0      0.0      Western  46.927528
# 2010005   1.1   0.9    0.0    0.0      0.0      0.0      Western  46.927528
#
#                 lon
# bus_id
# 2010001 -124.577777
# 2010002 -124.183645
# 2010003 -124.056969
# 2010004 -124.171950
# 2010005 -124.171950

# %%
bus_ba_map = western.bus[western.bus['Pd']>0][['Pd','lat','lon']].copy()
bus_ba_map.loc[:,'BA'] = None
bus_ba_map
# Out:
#             Pd        lat         lon    BA
# bus_id
# 2010001   9.64  48.241400 -124.577777  None
# 2010002  15.98  47.695555 -124.183645  None
# 2010003  14.39  47.040041 -124.056969  None
# 2010005  10.45  46.927528 -124.171950  None
# 2010006  13.44  46.316481 -124.061190  None
# 2010009  16.82  46.498255 -123.982546  None
# 2010010  33.49  47.174349 -123.847397  None
# 2010011  32.02  48.002536 -123.762001  None
# 2010013  57.79  47.164996 -123.663897  None
# 2010015  25.01  47.188929 -123.686007  None
# 2010017  25.89  46.655960 -123.614788  None
# 2010018  24.47  47.071872 -123.294346  None
# 2010020  53.35  47.987959 -123.331982  None
# 2010021   8.99  46.190358 -123.332028  None
# 2010022  48.19  47.150371 -123.130049  None
# 2010024  43.96  47.147901 -123.071736  None
# 2010025  30.89  46.791791 -123.041825  None
# 2010026  18.65  48.626752 -123.037525  None
# 2010028  32.23  48.087401 -123.157993  None
# 2010029  32.23  48.002379 -123.081743  None
# 2010031  39.80  47.022846 -123.132450  None
# 2010032  41.50  47.067281 -123.143333  None
# 2010033  59.05  46.127668 -123.010999  None
# 2010035  59.05  46.146733 -122.989382  None
# 2010037  58.29  46.659985 -122.962879  None
# 2010038  36.59  47.143308 -123.021254  None
# 2010040  43.57  47.171712 -122.922797  None
# 2010041  20.08  46.418666 -122.895750  None
# 2010042  59.25  46.754791 -122.848111  None
# 2010044  37.54  47.453521 -122.926406  None
# ...        ...        ...         ...   ...
# 2080023  29.94  31.806563 -106.372068  None
# 2080024  29.94  31.691022 -106.346955  None
# 2080025   6.89  31.854885 -106.497928  None
# 2080026  33.96  31.921358 -106.405461  None
# 2080027  34.31  31.921358 -106.405461  None
# 2080029  67.92  31.976731 -106.387693  None
# 2080031  10.06  31.747204 -106.409029  None
# 2080032   8.45  31.805616 -106.453299  None
# 2080034  46.07  31.768004 -106.323185  None
# 2080035  46.07  31.723717 -106.301503  None
# 2080036  46.74  31.852428 -106.406570  None
# 2080037  46.74  31.886260 -106.354058  None
# 2080039  41.50  31.787616 -106.257455  None
# 2080043  63.40  31.676442 -106.304317  None
# 2080044  63.40  31.610078 -106.299010  None
# 2080046  85.17  31.818920 -106.260575  None
# 2080047  85.17  31.762311 -106.216284  None
# 2080050  85.17  31.803476 -106.354992  None
# 2080055  44.87  31.691051 -106.334786  None
# 2080059  44.87  31.644209 -106.319432  None
# 2080061  30.38  31.618526 -106.235805  None
# 2080066  13.28  31.486219 -106.201346  None
# 2080067  20.01  31.544999 -106.149619  None
# 2080070  56.98  31.551941 -106.139122  None
# 2080072  56.98  31.577336 -106.191343  None
# 2080073   8.58  31.431155 -105.981590  None
# 2080075  61.55  31.917912 -105.937686  None
# 2080078  61.55  31.917393 -105.990960  None
# 2080081   4.46  31.400937 -105.974373  None
# 2080084   1.47  31.270907 -105.233641  None
#
# [4170 rows x 4 columns]

# %%
# importing the requests library 
import requests
from collections import Counter
  
# api-endpoint 
URL = "https://geo.fcc.gov/api/census/block/find"
# defining a params dict for the parameters to be sent to the API
count = 0
county_bus_num_count = Counter()
for index,row in bus_ba_map.iterrows():
    PARAMS = {'latitude':row['lat'], 'longitude':row['lon'], 'format':'json', 'showall': True} 

    # sending get request and saving the response as response object 
    r = requests.get(url = URL, params = PARAMS).json()
    try:
        county_ba_dict[r['County']['name']+'_'+r['State']['code']]
    except Exception as err:
        count += 1
        continue
    county_name = r['County']['name']+'_'+r['State']['code']
    county_bus_num_count[county_name] += 1
    ba_num = len(county_ba_dict[county_name])
    bus_ba_map.at[index,'BA'] = county_ba_dict[county_name][county_bus_num_count[county_name]%ba_num]
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-151-ef24384df477> in <module>
#      21     county_bus_num_count[county_name] += 1
#      22     ba_num = len(county_ba_dict[county_name])
# ---> 23     bus_ba_map.at[index,'BA'] = county_ba_dict[county_name][county_bus_num_count[county_name]%ba_num]
#
# ZeroDivisionError: integer division or modulo by zero

# %%
bus_ba_map
# Out:
#             Pd        lat         lon    BA
# bus_id
# 2010001   9.64  48.241400 -124.577777  BPAT
# 2010002  15.98  47.695555 -124.183645  BPAT
# 2010003  14.39  47.040041 -124.056969  BPAT
# 2010005  10.45  46.927528 -124.171950  BPAT
# 2010006  13.44  46.316481 -124.061190  BPAT
# 2010009  16.82  46.498255 -123.982546  BPAT
# 2010010  33.49  47.174349 -123.847397  BPAT
# 2010011  32.02  48.002536 -123.762001  BPAT
# 2010013  57.79  47.164996 -123.663897  BPAT
# 2010015  25.01  47.188929 -123.686007  BPAT
# 2010017  25.89  46.655960 -123.614788  BPAT
# 2010018  24.47  47.071872 -123.294346  BPAT
# 2010020  53.35  47.987959 -123.331982  BPAT
# 2010021   8.99  46.190358 -123.332028  BPAT
# 2010022  48.19  47.150371 -123.130049  TPWR
# 2010024  43.96  47.147901 -123.071736  BPAT
# 2010025  30.89  46.791791 -123.041825  PSEI
# 2010026  18.65  48.626752 -123.037525  BPAT
# 2010028  32.23  48.087401 -123.157993  BPAT
# 2010029  32.23  48.002379 -123.081743  BPAT
# 2010031  39.80  47.022846 -123.132450  BPAT
# 2010032  41.50  47.067281 -123.143333  PSEI
# 2010033  59.05  46.127668 -123.010999  BPAT
# 2010035  59.05  46.146733 -122.989382  PACW
# 2010037  58.29  46.659985 -122.962879  TPWR
# 2010038  36.59  47.143308 -123.021254  TPWR
# 2010040  43.57  47.171712 -122.922797  BPAT
# 2010041  20.08  46.418666 -122.895750  BPAT
# 2010042  59.25  46.754791 -122.848111  TPWR
# 2010044  37.54  47.453521 -122.926406  BPAT
# ...        ...        ...         ...   ...
# 2080023  29.94  31.806563 -106.372068  None
# 2080024  29.94  31.691022 -106.346955  None
# 2080025   6.89  31.854885 -106.497928  None
# 2080026  33.96  31.921358 -106.405461  None
# 2080027  34.31  31.921358 -106.405461  None
# 2080029  67.92  31.976731 -106.387693  None
# 2080031  10.06  31.747204 -106.409029  None
# 2080032   8.45  31.805616 -106.453299  None
# 2080034  46.07  31.768004 -106.323185  None
# 2080035  46.07  31.723717 -106.301503  None
# 2080036  46.74  31.852428 -106.406570  None
# 2080037  46.74  31.886260 -106.354058  None
# 2080039  41.50  31.787616 -106.257455  None
# 2080043  63.40  31.676442 -106.304317  None
# 2080044  63.40  31.610078 -106.299010  None
# 2080046  85.17  31.818920 -106.260575  None
# 2080047  85.17  31.762311 -106.216284  None
# 2080050  85.17  31.803476 -106.354992  None
# 2080055  44.87  31.691051 -106.334786  None
# 2080059  44.87  31.644209 -106.319432  None
# 2080061  30.38  31.618526 -106.235805  None
# 2080066  13.28  31.486219 -106.201346  None
# 2080067  20.01  31.544999 -106.149619  None
# 2080070  56.98  31.551941 -106.139122  None
# 2080072  56.98  31.577336 -106.191343  None
# 2080073   8.58  31.431155 -105.981590  None
# 2080075  61.55  31.917912 -105.937686  None
# 2080078  61.55  31.917393 -105.990960  None
# 2080081   4.46  31.400937 -105.974373  None
# 2080084   1.47  31.270907 -105.233641  None
#
# [4170 rows x 4 columns]

# %%
county_name = 'Lincoln_NV'
county_ba_dict[county_name]
# county_name
# Out:
# []

# %%
count
# Out:
# 3

# %%
county_bus_num_count
# Out:
# Counter({'Clallam_WA': 1,
#          'Jefferson_WA': 1,
#          'Grays Harbor_WA': 4,
#          'Pacific_WA': 4})

# %%
county_ba_dict['Pacific_WA']
# Out:
# ['BPAT']
